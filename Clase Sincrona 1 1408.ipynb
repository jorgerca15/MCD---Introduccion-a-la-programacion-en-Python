# %% [markdown]
# ## Problema 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Problema 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
tupla_mes_max = max_lluvias(lluvia)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# def max_lluviar(lista):
#     mes_actual = lista[0]
#     lluvia_mes_actual = []
#     for i in range(1,len(lista)):

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Problema 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ·
