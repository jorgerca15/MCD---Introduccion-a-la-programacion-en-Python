# %% [markdown]
# ## **Listas**

# %% [markdown]
# ### Tema 1: Definicion de listas y acceso a sus elementos

# %% [markdown]
# - Una lista guarda una secuencia de elementos
# - Un elemento en cada casillero
# - Cada casillero puede guardar un distinto tipo de elemento
# - Listas son mutables: podemos cambiarlos cuando necesitamos
# - Pueden crecer segun necesidades del programa mediante append e insert
# - Elementos puedes ser eliminados mediante remove y pop
#
# Imaginemos que queremos guardar la temperatura de la semana

# %%
temp = [30.5,19.8,12.3,31.0,19.9,34.4,25.3]
print(temp[0])
print(temp[3:5])
# Out:
# 30.5
# [31.0, 19.9]

# %% [markdown]
# Las listas se pueden modificar:

# %%
temp[2] = 22.3
print(temp)
# Out:
# [30.5, 19.8, 22.3, 31.0, 19.9, 34.4, 25.3]

# %% [markdown]
# ### Tema 2: Como recorrer una lista

# %%
print(len(temp))
# Out:
# 7

# %% [markdown]
# Recorrer una lisat con la funcion for in range: Modo 1

# %%
for i in range(len(temp)):
    print(temp[i])
# Out:
# 30.5
# 19.8
# 22.3
# 31.0
# 19.9
# 34.4
# 25.3

# %% [markdown]
# Recorrer una lisat con la funcion for range: Modo 2

# %%
for elem in temp:
    print(elem)
# Out:
# 30.5
# 19.8
# 22.3
# 31.0
# 19.9
# 34.4
# 25.3

# %% [markdown]
# ### Tema 3: Como agregar elementos a una lista

# %%
# Metodos

#Siempre inserta el elemento al final de la lista
temp.append(21.3) 

# Para colocar el elemento en la posición deseada
temp.insert(5,16.5)

print(temp)
# Out:
# [30.5, 19.8, 22.3, 31.0, 19.9, 16.5, 12.5, 12.5, 34.4, 25.3, 18.3, 25.6, 27.0, 21.3]

# %%
temp[10] = 25.6
temp[11] = 27.0
print(temp)

print(len(temp))
# Out:
# [30.5, 19.8, 22.3, 31.0, 19.9, 16.5, 12.5, 12.5, 34.4, 25.3, 25.6, 27.0, 27.0, 21.3]
# 14

# %% [markdown]
# ### Tema 4: Eliminar elementos de una lista

# %%
# Metodo remove
temp.remove(12.5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 2
#       1 # Metodo remove
# ----> 2 temp.remove(12.5)
#       4 # Verificamos el nro de elementos
#       5 print(temp)
#
# ValueError: list.remove(x): x not in list

# %%
# Metodo pop: Elimina segun la posicion y retorna el valor del elemento que elimina.

elem = temp.pop(4) # Asignamos una variable elem

# %%
# Verificamos el nro de elementos
print(temp)
print(len(temp))
# Out:
# [30.5, 19.8, 22.3, 31.0, 16.5, 34.4, 25.3, 25.6, 27.0, 27.0, 21.3]
# 11

# %% [markdown]
# ### Tema 5: Metodos adicionales de listas

# %%
# Metodo index:

temp = [30.5, 19.8, 22.3, 31.0, 16.5, 34.4, 25.3]
dias = ['Lu','Ma','Mi','Ju','Vi','Sa','Do'] # Creamos la lista dias
# print(dias)
temperatura = 22.3

if temperatura in temp:
    ind = temp.index(temperatura)
    print(dias[ind])
# Out:
# Mi

# %% [markdown]
# ## **Tuplas**

# %% [markdown]
# ### Tema 1 : que es una tupla

# %% [markdown]
# - Coleccion ordenada e inmutable de elementos del mismo o diferente tipo
# - Al igual que con las listas, para la selección se usan corchetes []
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Tema 2: Diferencia entre listas y tuplas

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
d = ('Lu','Ma','Mi','Ju','Vi','Sa','Do') # Creamos la tupla dias
print(d[3])
# Out:
# Ju

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - listas [] -> mutables (si se pueden modifiar)
#
# - tuplas() -> inmutables (no pueden modificarse)

# %% [markdown]
# ### Tema 3: Creacion de tuplas

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### **Nota:** Los parentesis se usan usualmente, pero no son obligatorios

# %% [markdown]
# ### Tema 4: Manejo de tuplas

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
m1 = ('Toy Story', 1995, '01:21',['animacion','comedia']) #creando la tupla
(nombre, anno, duracion, categorias) = m1 

print(anno)
print(categorias)
# Out:
# 1995
# ['animacion', 'comedia']

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Esto se usa para ordenar listas
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Tema 5: Retorno de una funcion

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Creacion de una funcion para convertir las tazas de harina

def convertir(taza):
    g = taza*1.25
    o = taza*4.41
    l = taza*0.28

    return g,o,l # Retornar 3 valores separados por coma como una tupla

# Evaluando los valores

gramos, onzas, libras = convertir(1.5)
print(gramos)



print(convertir(1.5))
# Out:
# 1.875
# (1.875, 6.615, 0.42000000000000004)

# %% [markdown]
# ## **Cuestionario formativo**

# %%
# Pregunta 1
lista = [1, 2, 4, 5, 6, 7, 8, 9]

lista.insert(2,3)

print(lista)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
# Pregunta 2:
lista = [1, 2, 7, 4, 5, 6, 3, 8, 9]

lista[2] = 3
lista[6] = 7

print(lista)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
# Pregunta 3: 
lista = ['Alicia', 1998, 'Bob', 1990, 'Carlos', 1986, 'David', 2001]
print(len(lista))


for i in range(len(lista)//2):
    nombre = lista[2*i]
    nac = lista[2*i+1]
    print(nombre,nac)
# Out:
# 8
# Alicia 1998
# Bob 1990
# Carlos 1986
# David 2001

# %%
# Pregunta 4:

lista = ['Alicia', 'Bob', 'Carlos', 'David']
lista2 = []


#for i in range(len(lista)):
#    cliente_pop = lista[len(lista)-i]
#    print(cliente_pop)



# Forma 1

# i = len(lista) - 1
# print(i)

# while i >= 0:
#    lista2 = lista.pop(i)
#    i = i - 1
#    print(lista2)


# Forma 2:
while len(lista) > 0:
    ultimo_cliente = len(lista)-1
    cliente =  lista.pop(ultimo_cliente)
    print(cliente)
# Out:
# David
# Carlos
# Bob
# Alicia

# %%
print(lista)
# Out:
# []

# %%
# Pregunta 5: 

d = ['Alicia', 'Bob', 'Carlos', 'David']

m = ['Pelusa', 'Luke', 'Mickey', 'Madonna']


for i in range(len(d)):
    print(d[i],m[i])
# Out:
# Alicia Pelusa
# Bob Luke
# Carlos Mickey
# David Madonna

# %%
# Pregunta 6: 

# Metodo 1
lista = ['soleado', 'nublado', 'soleado', 'lluvia', 2.4, 'lluvia', 0.1, 'nublado', 'lluvia', 0.8]

suma = 0 

for elemento in lista:
    if elemento not in ['soleado', 'nublado', 'lluvia']:
        suma += elemento
print(suma)
# Out:
# 3.3

# %%
# Pregunta 6: 

# Metodo 2
lista = ['soleado', 'nublado', 'soleado', 'lluvia', 2.4, 'lluvia', 0.1, 'nublado', 'lluvia', 0.8]

suma = 0 
for i in range(len(lista)):
    if lista[i] != 'lluvia' and lista[i] != 'nublado' and lista[i] != 'soleado':
        suma+=lista[i]
print(suma)
# Out:
# 3.3

# %% [markdown]
# ## **Actividad Sumativa 1**

# %%
# Pregunta 1

tupla = ('Camila', 5.0, 6.2, 4.8, 6.0)

def  calcular_promedio(tupla):
    nombre = tupla[0]
    promedio = (tupla[1] + tupla[2] + tupla[3] + tupla[4])/4
    tupla2 = nombre,promedio
    return tupla2

tupla2 = calcular_promedio(tupla)
print(tupla2)
# Out:
# ('Camila', 5.5)

# %%
# Pregunta 2

lista = [-40, -1, 2, 5, 16, 72, 100]
print(lista)
# Out:
# [-40, -1, 2, 5, 16, 72, 100]

# %%
def agregar_entero(lista, entero):
    for i in range(len(lista)):
        if entero < lista[i]:
            lista.insert(i,entero)
            break
        elif entero > lista[len(lista)-1]:
            lista.insert(len(lista),entero)
            break
    return lista

agregar_entero(lista,99)
print(lista)
# Out:
# [-40, -1, 2, 5, 16, 72, 99, 100, 101, 102]

# %%
# Pregunta 3

lista = [1, 4, 3, 1, 4, 2, 5, 1, 2, 4, 1, 3, 1, 2, 4]

def contar_repeticiones(lista):
    lista_temp = []
    count1 = 0
    count2 = 0
    count3 = 0
    count4 = 0
    count5 = 0
    for i in range(len(lista)):
        if lista[i] == 1:
            count1 += 1
        elif lista[i] == 2:
            count2 += 1
        elif lista[i] == 3:
            count3 += 1
        elif lista[i] == 4:
            count4 += 1
        elif lista[i] == 5:
            count5 += 1
    lista_temp = (count1,count2,count3,count4,count5)
    m = max(lista_temp)
    return m

contar_repeticiones(lista)
# Out:
# (5, 3, 2, 4, 1)
# 5

# %%
# Pregunta 4

lista = ['Francisca Avedaño', 'Pablo Avedaño', 'Juan Bravo', 'Javiera Hernández', 'Mario Huerta', 'David Morales', 'Eliza Morales']

def  agregar_estudiante(lista, estudiante):
    for i in range(len(lista[0])):
        if estudiante

# %%
lista = ['Francisca Avedaño', 'Pablo Avedaño', 'Juan Bravo', 'Javiera Hernández', 'Mario Huerta', 'David Morales', 'Eliza Morales']
lista_n = []
lista_a = []

# Obteniendo las primeras letras de cada nombre
for i in range(len(lista)):
    for j in range(len(lista[i])):
        if j == 0:
            lista_n.append(lista[i][j])
            break
print(lista_n)

#Obteniendo las primeras letras de cada apellido
for i in range(len(lista)):
    for j in range(len(lista[i])):
        if lista[i][j] == " ":
            lista_a.append(lista[i][j+1])
            break
print(lista_a)


def agregar_estudiante(lista, estudiante):
# Out:
# ['F', 'P', 'J', 'J', 'M', 'D', 'E']
# ['A', 'A', 'B', 'H', 'H', 'M', 'M']
